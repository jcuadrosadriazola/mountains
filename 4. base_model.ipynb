# %% [markdown]
# # Confined transient (small streams) – base model
#
# Set up the confined transient MODFLOW 6 model using the locally prepared inputs under `mountain/`. This mirrors the earlier `Confined_version_transient_smallstreams` workflow but pulls rasters/NPZ from the new folders so it can run self-contained.

# %%
import os
from pathlib import Path
import math
import numpy as np
import pandas as pd
import geopandas as gpd
import shapefile as sf
from shapely.geometry import Polygon
import shutil

import flopy
from flopy.discretization import StructuredGrid
from flopy.utils.gridintersect import GridIntersect

print('flopy version:', flopy.__version__)

# Paths
mountain_dir = Path('/home/jec18/modflow/jupy/VUB/mountain')
reproj_dir = mountain_dir / 'reprojected'
reproj_rasters = reproj_dir / 'rasters'
reproj_vectors = reproj_dir / 'vectors'
prepared_dir = mountain_dir / 'prepared'

pre_npz = prepared_dir / 'preprocessed_confined_inputs.npz'
if not pre_npz.exists():
    raise FileNotFoundError(f"Missing preprocessed NPZ: {pre_npz}")

catchment_path = Path('/home/jec18/catchments/km105.shp')
# Use rivers from the clipped/reprojected prep (HydroRIVERS) instead of the old psad shapefile
rivers_path = reproj_vectors / 'rivers_hydrorivers_psad.gpkg'
if not rivers_path.exists():
    rivers_path = Path('/home/jec18/datasets/gw/psad/rivers_valid/rivers_sfr.shp')
workspace = mountain_dir / 'base_model'
# clean workspace each run
if workspace.exists():
    shutil.rmtree(workspace)
workspace.mkdir(exist_ok=True)
name = 'vub'
# Out:
# flopy version: 3.9.5

# %% [markdown]
# ## Grid and inputs from NPZ
# Use the prepared NPZ to rebuild the StructuredGrid, arrays, and recharge/ET stacks.

# %%
data = np.load(pre_npz)
resolution = int(data['resolution'])
xmin = float(data['xmin'])
ymin = float(data['ymin'])
nrow = int(data['nrow'])
ncol = int(data['ncol'])

# Rebuild grid
delr = resolution * np.ones(ncol, dtype=float)
delc = resolution * np.ones(nrow, dtype=float)
top = np.full((nrow, ncol), 1.0)
botm = np.full((1, nrow, ncol), 0.0)

struct_grid = StructuredGrid(
    nlay=1,
    delr=delr,
    delc=delc,
    xoff=xmin,
    yoff=ymin,
    top=top,
    botm=botm,
)
struct_grid.idomain = data['idomain'].reshape(struct_grid.shape)

# Arrays
pre_topo = data['topo']
k_h_data = data['k_h_data']
k_h_data2 = data['k_h_data2']
recharge_data = data['recharge_data']
deposits = data['deposits']
bedrock = data['bedrock']

print('Grid shape:', struct_grid.shape)
# Out:
# Grid shape: (1, 608, 678)

# %%
# Load rivers for potential RIV/DRN setup
rivers_gdf = gpd.read_file(rivers_path)
if rivers_gdf.crs is None:
    rivers_gdf = rivers_gdf.set_crs('EPSG:4326')
rivers_gdf = rivers_gdf.to_crs(epsg=24893)
print('Rivers loaded:', rivers_path)
print('Rivers CRS:', rivers_gdf.crs)
# Out:
# Rivers loaded: /home/jec18/modflow/jupy/VUB/mountain/reprojected/vectors/rivers_hydrorivers_psad.gpkg
# Rivers CRS: EPSG:24893

# %% [markdown]
# ## Time discretization
# Steady-state spinup + transient monthly periods (10 years). Adjust as needed.

# %%
spinup_years = 10
months_per_year = 12
nper_tr = spinup_years * months_per_year
nper_total = 1 + nper_tr

days_per_month = 30.44
seconds_per_day = 86400
perlen = [1.0] + [days_per_month * seconds_per_day] * nper_tr
nstp   = [1] + [3] * nper_tr
tsmult = [1.0] * nper_total
sp_type = ['SS'] + ['TR'] * nper_tr

# %% [markdown]
# ## Build MODFLOW 6 simulation
# Sets up DIS, IC, NPF, STO, RCH with monthly files. River/Drain packages can be added using the same pattern as the prior notebook (see placeholder section).

# %%
# Prepare recharge text files in workspace
workspace_path = Path(workspace)
monthly_rch = recharge_data[1:]
month_files = []
for month_idx, arr in enumerate(monthly_rch, start=1):
    fname = workspace_path / f"recharge_month_{month_idx:02d}.txt"
    np.savetxt(fname, arr)
    month_files.append(fname.name)
ss_file = workspace_path / "recharge_steady.txt"
np.savetxt(ss_file, recharge_data[0])

# Build simulation
sim = flopy.mf6.MFSimulation(sim_ws=str(workspace_path), exe_name='mf6', verbosity_level=2)
tdis = flopy.mf6.ModflowTdis(sim, time_units='seconds', nper=nper_total, perioddata=list(zip(perlen, nstp, tsmult)))
gwf = flopy.mf6.ModflowGwf(sim, modelname=name, save_flows=True, print_input=True)
ims = flopy.mf6.ModflowIms(sim, complexity='simple', print_option='SUMMARY', linear_acceleration='bicgstab')

dis = flopy.mf6.ModflowGwfdis(
    gwf,
    nlay=1,
    nrow=nrow,
    ncol=ncol,
    delr=delr,
    delc=delc,
    top=1,
    botm=0,
    xorigin=xmin,
    yorigin=ymin,
    idomain=struct_grid.idomain,
    length_units='METERS'
)

ic = flopy.mf6.ModflowGwfic(gwf, strt=pre_topo)

# Hydraulic conductivity
k = np.zeros((1, nrow, ncol))
k[0, :, :] = (k_h_data * 40 + k_h_data2 * 100) / 140
k = np.nan_to_num(k, nan=1e-12)

npf = flopy.mf6.ModflowGwfnpf(gwf, icelltype=0, k=k, save_specific_discharge=True)

sto = flopy.mf6.ModflowGwfsto(
    gwf,
    save_flows=True,
    ss=3e-2,
    steady_state={0: True},
    transient={1: True}
)

# Recharge package

def openclose(name):
    return ['open/close', name, 'factor', 1.0]

rch_spd = {0: openclose(ss_file.name)}
for kper in range(1, nper_total):
    month_idx = (kper - 1) % len(month_files)
    rch_spd[kper] = openclose(month_files[month_idx])

rch = flopy.mf6.ModflowGwfrcha(gwf, print_flows=True, recharge=rch_spd)

# Output control
budget_file = f"{name}.bud"
head_file = f"{name}.hds"
oc = flopy.mf6.ModflowGwfoc(
    gwf,
    budget_filerecord=budget_file,
    head_filerecord=head_file,
    saverecord=[('HEAD', 'ALL'), ('BUDGET', 'ALL')]
)

# %% [markdown]
# ## Rivers and drains
# Generate RIV/DRN packages from the clipped rivers, separating major (> Strahler 2) and minor (<=2) streams, and write stress-period data to external template files.

# %% [markdown]
# ## Run simulation

# %%
from shapely.geometry import LineString, MultiLineString

# Build river multilines (split by Strahler order)
order_col = 'ORD_STRA' if 'ORD_STRA' in rivers_gdf.columns else None
if order_col is None:
    for cand in ['ord_stra', 'strahler', 'STRAHLER']:
        if cand in rivers_gdf.columns:
            order_col = cand
            break
if order_col is None:
    raise ValueError('Could not find Strahler order column in rivers_gdf')

riverlist = []
smallstream_list = []
order_threshold = 2
for geom, order in zip(rivers_gdf.geometry, rivers_gdf[order_col]):
    if geom is None or geom.is_empty:
        continue
    parts = list(geom.geoms) if geom.geom_type == 'MultiLineString' else [geom]
    order_val = float(order)
    target_list = riverlist if order_val > order_threshold else smallstream_list
    for part in parts:
        if part.is_empty:
            continue
        target_list.append(LineString(part))

riv = MultiLineString(riverlist) if riverlist else None
minor_riv = MultiLineString(smallstream_list) if smallstream_list else None

ix = GridIntersect(struct_grid)
ixs = ix.intersect(riv) if riv is not None else []
ixs_minor = ix.intersect(minor_riv) if minor_riv is not None else []

# River stress-period data
active_idomain = struct_grid.idomain[0]
riv_data = []
for inter in ixs:
    if active_idomain[inter.cellids] > 0:
        riverbed = pre_topo[inter.cellids]
        cond = 1e-4 * inter.lengths * 30.0
        stage = riverbed - 5.0
        riv_data.append(((0, *inter.cellids), riverbed, cond, stage))

# Drains for minor streams
drains_width = 2.0
drn_data = []
minor_cells = set()
for inter in ixs_minor:
    if active_idomain[inter.cellids] > 0:
        stage = pre_topo[inter.cellids] - 1.0
        cond = 1e-5 * inter.lengths * drains_width
        drn_data.append(((0, *inter.cellids), stage, cond))
        minor_cells.add(tuple(inter.cellids))

# Diffuse drains elsewhere
background_cond = 1e-10 * (resolution ** 2)
drn_dif_data = []
active_indices = np.argwhere(active_idomain > 0)
for row, col in active_indices:
    if (row, col) in minor_cells:
        continue
    stage = pre_topo[row, col]
    drn_dif_data.append(((0, row, col), stage, background_cond))

# Write to external files
def write_list_records(path, records):
    with path.open("w") as f:
        for (lay, row, col), *vals in records:
            lay += 1
            row += 1
            col += 1
            f.write(f"{lay:3d} {row:3d} {col:3d} " + " ".join(f"{v:.8g}" for v in vals) + "\n")
riv_file = workspace_path / "riv_template.dat"
write_list_records(riv_file, riv_data)

riv_spd = {k: {"filename": riv_file.name} for k in range(nper_total)}

mfriv = flopy.mf6.ModflowGwfriv(
    gwf,
    stress_period_data=riv_spd,
    save_flows=True,
    filename="model.riv",
)

drn_file = workspace_path / "drn_template.dat"
write_list_records(drn_file, drn_data)

drn_spd = {k: {"filename": drn_file.name} for k in range(nper_total)}

drn = flopy.mf6.ModflowGwfdrn(
    gwf,
    stress_period_data=drn_spd,
    save_flows=True,
    filename="model.drn",
    pname="DRN-riv"
)

drn_dif_file = workspace_path / "drn_dif_template.dat"
write_list_records(drn_dif_file, drn_dif_data)

drn_dif_spd = {k: {"filename": drn_dif_file.name} for k in range(nper_total)}

drn_dif = flopy.mf6.ModflowGwfdrn(
    gwf,
    stress_period_data=drn_dif_spd,
    save_flows=True,
    filename="model_dif.drn",
    pname="DRN-dif"
)
print('RIV/DRN packages added with external template files')
# Out:
# /home/jec18/hydro1/anaconda3/envs/gmdsitut/lib/python3.11/site-packages/flopy/utils/gridintersect.py:123: DeprecationWarning: Note `method="structured"` is deprecated. Pass `method="vertex"` to silence this warning. This will be the new default in a future release and this keyword argument will be removed.
#   warnings.warn(
# RIV/DRN packages added with external template files

# %%
sim.write_simulation()
success, buff = sim.run_simulation(report=True)
print('Simulation success:', success)
# Out:
# writing simulation...
#   writing simulation name file...
#       writing block options...
#         writing data continue...
#         writing data nocheck...
#         writing data memory_print_option...
#         writing data profile_option...
#         writing data maxerrors...
#         writing data print_input...
#         writing data hpc_filerecord...
#       writing block timing...
#         writing data tdis6...
#       writing block models...
#         writing data models...
#       writing block exchanges...
#         writing data exchanges...
#       writing block solutiongroup...
#         writing data mxiter (0)...
#         writing data solutiongroup (0)...
#   writing simulation tdis package...
#       writing block options...
#         writing data time_units...
#         writing data start_date_time...
#         writing data ats_filerecord...
#       writing block dimensions...
#         writing data nper...
#       writing block perioddata...
#         writing data perioddata...
#   writing solution package ims_-1...
#       writing block options...
#         writing data print_option...
#         writing data complexity...
#         writing data csv_output_filerecord...
#         writing data csv_outer_output_filerecord...
#         writing data csv_inner_output_filerecord...
#         writing data no_ptcrecord...
#         writing data ats_outer_maximum_fraction...
#       writing block nonlinear...
#       writing block linear...
#         writing data inner_maximum...
#         writing data inner_hclose...
#         writing data inner_dvclose...
#         writing data rcloserecord...
#         writing data linear_acceleration...
#         writing data relaxation_factor...
#         writing data preconditioner_levels...
#         writing data preconditioner_drop_tolerance...
#         writing data number_orthogonalizations...
#         writing data scaling_method...
#         writing data reordering_method...
#   writing model vub...
#     writing model name file...
#       writing block options...
#         writing data list...
#         writing data print_input...
#         writing data print_flows...
#         writing data save_flows...
#         writing data newtonoptions...
#         writing data nc_mesh2d_filerecord...
#         writing data nc_structured_filerecord...
#         writing data nc_filerecord...
#       writing block packages...
#         writing data packages...
#     writing package dis...
#       writing block options...
#         writing data length_units...
#         writing data nogrb...
#         writing data grb_filerecord...
#         writing data xorigin...
#         writing data yorigin...
#         writing data angrot...
#         writing data export_array_ascii...
#         writing data export_array_netcdf...
#         writing data ncf_filerecord...
#       writing block dimensions...
#         writing data nlay...
#         writing data nrow...
#         writing data ncol...
#       writing block griddata...
#         writing data delr...
#         writing data delc...
#         writing data top...
#         writing data botm...
#         writing data idomain...
#     writing package ic...
#       writing block options...
#         writing data export_array_ascii...
#         writing data export_array_netcdf...
#       writing block griddata...
#         writing data strt...
#     writing package npf...
#       writing block options...
#         writing data save_flows...
#         writing data print_flows...
#         writing data alternative_cell_averaging...
#         writing data thickstrt...
#         writing data cvoptions...
#         writing data perched...
#         writing data rewet_record...
#         writing data xt3doptions...
#         writing data save_specific_discharge...
#         writing data save_saturation...
#         writing data k22overk...
#         writing data k33overk...
#         writing data tvk_filerecord...
#         writing data export_array_ascii...
#         writing data export_array_netcdf...
#         writing data dev_no_newton...
#         writing data dev_omega...
#       writing block griddata...
#         writing data icelltype...
#         writing data k...
#         writing data k22...
#         writing data k33...
#         writing data angle1...
#         writing data angle2...
#         writing data angle3...
#         writing data wetdry...
#     writing package sto...
#       writing block options...
#         writing data save_flows...
#         writing data storagecoefficient...
#         writing data ss_confined_only...
#         writing data tvs_filerecord...
#         writing data export_array_ascii...
#         writing data export_array_netcdf...
#         writing data dev_original_specific_storage...
#         writing data dev_oldstorageformulation...
#       writing block griddata...
#         writing data iconvert...
#         writing data ss...
#         writing data sy...
#       writing block period...
#         writing data steady-state (0)...
#         writing data transient (0)...
#         writing data steady-state (1)...
#         writing data transient (1)...
#     writing package rcha_0...
#       writing block options...
#         writing data readasarrays...
#         writing data fixed_cell...
#         writing data auxiliary...
#         writing data auxmultname...
#         writing data print_input...
#         writing data print_flows...
#         writing data save_flows...
#         writing data tas_filerecord...
#         writing data obs_filerecord...
#         writing data export_array_netcdf...
#       writing block period...
#         writing data irch (0)...
#         writing data recharge (0)...
#         writing data aux (0)...
#         writing data irch (1)...
#         writing data recharge (1)...
#         writing data aux (1)...
#         writing data irch (2)...
#         writing data recharge (2)...
#         writing data aux (2)...
#         writing data irch (3)...
#         writing data recharge (3)...
#         writing data aux (3)...
#         writing data irch (4)...
#         writing data recharge (4)...
#         writing data aux (4)...
#         writing data irch (5)...
#         writing data recharge (5)...
#         writing data aux (5)...
#         writing data irch (6)...
#         writing data recharge (6)...
#         writing data aux (6)...
#         writing data irch (7)...
#         writing data recharge (7)...
#         writing data aux (7)...
#         writing data irch (8)...
#         writing data recharge (8)...
#         writing data aux (8)...
#         writing data irch (9)...
#         writing data recharge (9)...
#         writing data aux (9)...
#         writing data irch (10)...
#         writing data recharge (10)...
#         writing data aux (10)...
#         writing data irch (11)...
#         writing data recharge (11)...
#         writing data aux (11)...
#         writing data irch (12)...
#         writing data recharge (12)...
#         writing data aux (12)...
#         writing data irch (13)...
#         writing data recharge (13)...
#         writing data aux (13)...
#         writing data irch (14)...
#         writing data recharge (14)...
#         writing data aux (14)...
#         writing data irch (15)...
#         writing data recharge (15)...
#         writing data aux (15)...
#         writing data irch (16)...
#         writing data recharge (16)...
#         writing data aux (16)...
#         writing data irch (17)...
#         writing data recharge (17)...
#         writing data aux (17)...
#         writing data irch (18)...
#         writing data recharge (18)...
#         writing data aux (18)...
#         writing data irch (19)...
#         writing data recharge (19)...
#         writing data aux (19)...
#         writing data irch (20)...
#         writing data recharge (20)...
#         writing data aux (20)...
#         writing data irch (21)...
#         writing data recharge (21)...
#         writing data aux (21)...
#         writing data irch (22)...
#         writing data recharge (22)...
#         writing data aux (22)...
#         writing data irch (23)...
#         writing data recharge (23)...
#         writing data aux (23)...
#         writing data irch (24)...
#         writing data recharge (24)...
#         writing data aux (24)...
#         writing data irch (25)...
#         writing data recharge (25)...
#         writing data aux (25)...
#         writing data irch (26)...
#         writing data recharge (26)...
#         writing data aux (26)...
#         writing data irch (27)...
#         writing data recharge (27)...
#         writing data aux (27)...
#         writing data irch (28)...
#         writing data recharge (28)...
#         writing data aux (28)...
#         writing data irch (29)...
#         writing data recharge (29)...
#         writing data aux (29)...
#         writing data irch (30)...
#         writing data recharge (30)...
#         writing data aux (30)...
#         writing data irch (31)...
#         writing data recharge (31)...
#         writing data aux (31)...
#         writing data irch (32)...
#         writing data recharge (32)...
#         writing data aux (32)...
#         writing data irch (33)...
#         writing data recharge (33)...
#         writing data aux (33)...
#         writing data irch (34)...
#         writing data recharge (34)...
#         writing data aux (34)...
#         writing data irch (35)...
#         writing data recharge (35)...
#         writing data aux (35)...
#         writing data irch (36)...
#         writing data recharge (36)...
#         writing data aux (36)...
#         writing data irch (37)...
#         writing data recharge (37)...
#         writing data aux (37)...
#         writing data irch (38)...
#         writing data recharge (38)...
#         writing data aux (38)...
#         writing data irch (39)...
#         writing data recharge (39)...
#         writing data aux (39)...
#         writing data irch (40)...
#         writing data recharge (40)...
#         writing data aux (40)...
#         writing data irch (41)...
#         writing data recharge (41)...
#         writing data aux (41)...
#         writing data irch (42)...
#         writing data recharge (42)...
#         writing data aux (42)...
#         writing data irch (43)...
#         writing data recharge (43)...
#         writing data aux (43)...
#         writing data irch (44)...
#         writing data recharge (44)...
#         writing data aux (44)...
#         writing data irch (45)...
#         writing data recharge (45)...
#         writing data aux (45)...
#         writing data irch (46)...
#         writing data recharge (46)...
#         writing data aux (46)...
#         writing data irch (47)...
#         writing data recharge (47)...
#         writing data aux (47)...
#         writing data irch (48)...
#         writing data recharge (48)...
#         writing data aux (48)...
#         writing data irch (49)...
#         writing data recharge (49)...
#         writing data aux (49)...
#         writing data irch (50)...
#         writing data recharge (50)...
#         writing data aux (50)...
#         writing data irch (51)...
#         writing data recharge (51)...
#         writing data aux (51)...
#         writing data irch (52)...
#         writing data recharge (52)...
#         writing data aux (52)...
#         writing data irch (53)...
#         writing data recharge (53)...
#         writing data aux (53)...
#         writing data irch (54)...
#         writing data recharge (54)...
#         writing data aux (54)...
#         writing data irch (55)...
#         writing data recharge (55)...
#         writing data aux (55)...
#         writing data irch (56)...
#         writing data recharge (56)...
#         writing data aux (56)...
#         writing data irch (57)...
#         writing data recharge (57)...
#         writing data aux (57)...
#         writing data irch (58)...
#         writing data recharge (58)...
#         writing data aux (58)...
#         writing data irch (59)...
#         writing data recharge (59)...
#         writing data aux (59)...
#         writing data irch (60)...
#         writing data recharge (60)...
#         writing data aux (60)...
#         writing data irch (61)...
#         writing data recharge (61)...
#         writing data aux (61)...
#         writing data irch (62)...
#         writing data recharge (62)...
#         writing data aux (62)...
#         writing data irch (63)...
#         writing data recharge (63)...
#         writing data aux (63)...
#         writing data irch (64)...
#         writing data recharge (64)...
#         writing data aux (64)...
#         writing data irch (65)...
#         writing data recharge (65)...
#         writing data aux (65)...
#         writing data irch (66)...
#         writing data recharge (66)...
#         writing data aux (66)...
#         writing data irch (67)...
#         writing data recharge (67)...
#         writing data aux (67)...
#         writing data irch (68)...
#         writing data recharge (68)...
#         writing data aux (68)...
#         writing data irch (69)...
#         writing data recharge (69)...
#         writing data aux (69)...
#         writing data irch (70)...
#         writing data recharge (70)...
#         writing data aux (70)...
#         writing data irch (71)...
#         writing data recharge (71)...
#         writing data aux (71)...
#         writing data irch (72)...
#         writing data recharge (72)...
#         writing data aux (72)...
#         writing data irch (73)...
#         writing data recharge (73)...
#         writing data aux (73)...
#         writing data irch (74)...
#         writing data recharge (74)...
#         writing data aux (74)...
#         writing data irch (75)...
#         writing data recharge (75)...
#         writing data aux (75)...
#         writing data irch (76)...
#         writing data recharge (76)...
#         writing data aux (76)...
#         writing data irch (77)...
#         writing data recharge (77)...
#         writing data aux (77)...
#         writing data irch (78)...
#         writing data recharge (78)...
#         writing data aux (78)...
#         writing data irch (79)...
#         writing data recharge (79)...
#         writing data aux (79)...
#         writing data irch (80)...
#         writing data recharge (80)...
#         writing data aux (80)...
#         writing data irch (81)...
#         writing data recharge (81)...
#         writing data aux (81)...
#         writing data irch (82)...
#         writing data recharge (82)...
#         writing data aux (82)...
#         writing data irch (83)...
#         writing data recharge (83)...
#         writing data aux (83)...
#         writing data irch (84)...
#         writing data recharge (84)...
#         writing data aux (84)...
#         writing data irch (85)...
#         writing data recharge (85)...
#         writing data aux (85)...
#         writing data irch (86)...
#         writing data recharge (86)...
#         writing data aux (86)...
#         writing data irch (87)...
#         writing data recharge (87)...
#         writing data aux (87)...
#         writing data irch (88)...
#         writing data recharge (88)...
#         writing data aux (88)...
#         writing data irch (89)...
#         writing data recharge (89)...
#         writing data aux (89)...
#         writing data irch (90)...
#         writing data recharge (90)...
#         writing data aux (90)...
#         writing data irch (91)...
#         writing data recharge (91)...
#         writing data aux (91)...
#         writing data irch (92)...
#         writing data recharge (92)...
#         writing data aux (92)...
#         writing data irch (93)...
#         writing data recharge (93)...
#         writing data aux (93)...
#         writing data irch (94)...
#         writing data recharge (94)...
#         writing data aux (94)...
#         writing data irch (95)...
#         writing data recharge (95)...
#         writing data aux (95)...
#         writing data irch (96)...
#         writing data recharge (96)...
#         writing data aux (96)...
#         writing data irch (97)...
#         writing data recharge (97)...
#         writing data aux (97)...
#         writing data irch (98)...
#         writing data recharge (98)...
#         writing data aux (98)...
#         writing data irch (99)...
#         writing data recharge (99)...
#         writing data aux (99)...
#         writing data irch (100)...
#         writing data recharge (100)...
#         writing data aux (100)...
#         writing data irch (101)...
#         writing data recharge (101)...
#         writing data aux (101)...
#         writing data irch (102)...
#         writing data recharge (102)...
#         writing data aux (102)...
#         writing data irch (103)...
#         writing data recharge (103)...
#         writing data aux (103)...
#         writing data irch (104)...
#         writing data recharge (104)...
#         writing data aux (104)...
#         writing data irch (105)...
#         writing data recharge (105)...
#         writing data aux (105)...
#         writing data irch (106)...
#         writing data recharge (106)...
#         writing data aux (106)...
#         writing data irch (107)...
#         writing data recharge (107)...
#         writing data aux (107)...
#         writing data irch (108)...
#         writing data recharge (108)...
#         writing data aux (108)...
#         writing data irch (109)...
#         writing data recharge (109)...
#         writing data aux (109)...
#         writing data irch (110)...
#         writing data recharge (110)...
#         writing data aux (110)...
#         writing data irch (111)...
#         writing data recharge (111)...
#         writing data aux (111)...
#         writing data irch (112)...
